# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **sports or athletics** (see below) for the region of **Ann Arbor, Michigan, United States**, or **United States** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Ann Arbor, Michigan, United States** to Ann Arbor, USA. In that case at least one source file must be about **Ann Arbor, Michigan, United States**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Ann Arbor, Michigan, United States** and **sports or athletics**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **sports or athletics**?  For this category we are interested in sporting events or athletics broadly, please feel free to creatively interpret the category when building your research question!
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %%
import pandas as pd

apps=pd.read_csv('applications.csv')
jobs=pd.read_csv('job_posts.csv')

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.figure as figure
import matplotlib.patches as mpatches
import seaborn as sns
# %matplotlib notebook
# %matplotlib inline

# %%
jobs.head(5)
# Out:
#          id        city                        job_title  \
# 0   516e4ed        Ciro          Sales & Marketing Agent
# 1  a361ef59       Cairo     German Training Coordinator
# 2  7226ce78       Cairo       Junior Software Developer
# 3  f4b2bcd6       Cairo     Application Support Engineer
# 4  3fee6f73  Alexandria  Electrical Maintenance Engineer
#
#                        job_category1   job_category2    job_category3  \
# 0  Sales/Retail/Business Development       Marketing           Select
# 1           Customer Service/Support  Administration  Human Resources
# 2            IT/Software Development          Select           Select
# 3            IT/Software Development          Select           Select
# 4                        Engineering          Select           Select
#
#                      job_industry1              job_industry2 job_industry3  \
# 0      Telecommunications Services                     Select        Select
# ...

# %%
apps.head()
# Out:
#          id   user_id   job_id             app_date
# 0  ba7b8f17  846d013c  516e4ed  2014-01-01 07:27:52
# 1  30e1ae86  9d5e32c5  516e4ed  2014-01-01 08:20:42
# 2  d829a6b7  eb26a291  516e4ed  2014-01-01 10:30:37
# 3  3f985f37  7b5e68a8  516e4ed  2014-01-01 10:55:07
# 4   27e1695  76fa79b1  516e4ed  2014-01-01 11:00:26

# %%
jobs=jobs.rename(columns={'id':'job_id'})
res=pd.merge(jobs,apps,on='job_id',how='inner')

# %%
categoryVacancies = jobs.groupby(['job_category1'])['num_vacancies'].sum()
tot= categoryVacancies.sum()
categoryVacancies = categoryVacancies.sort_values(ascending=False)
categoryVacancies = categoryVacancies.head(5)
top5 = categoryVacancies.sum();

categoryVacancies.loc['Others']=tot-top5

colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen','lightpink']
explode = (0.1, 0.04, 0.04, 0.04, 0.04, 0.04) 
w , patches , text = plt.pie(categoryVacancies,explode=explode,colors=colors,autopct='%1.1f%%', shadow=True,startangle=0)

plt.legend(patches,labels = categoryVacancies.index,loc=6, bbox_to_anchor=(1, 0.5))
plt.axis('equal')
plt.title('Top 5 categories with maximum number of job vacancies')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:504: UserWarning: You have mixed positional and keyword arguments, some input will be discarded.
#   warnings.warn("You have mixed positional and keyword "

# %%
temp=res.groupby('job_industry1').size()
temp=temp.sort_values(ascending=True)
df=pd.DataFrame([temp.index,temp],['job_industry1','ct'])
df=df.transpose()


length=len(df)
fig, ax=plt.subplots(figsize=(length/4,length))
pos=np.arange(length)

ax=plt.gca()

ymarks=[i for i in range(1,length+1,1)]
ax.set_yticks(ymarks)
ax.barh(pos,df['ct'],align='center',tick_label=df['job_industry1'])
ax.set_yticklabels(df['job_industry1'],fontsize=25)
plt.xticks(fontsize=25)
plt.tight_layout()
plt.title('Number of Job Applications as per every industry',fontsize=35,color='black')
plt.show()
#sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 1.5})
#f, ax = plt.subplots(figsize=(12, 40))
#sns.set_palette(sns.hls_palette(8, l=.3, s=.8))
#sns.countplot(y='job_industry1',data=df,palette='Set3',order=df.ct,saturation=1)
#sns.plt.show()

# %%
industryVacancies = jobs.groupby(['job_industry1'])['num_vacancies'].sum()
tot= industryVacancies.sum()
industryVacancies = industryVacancies.sort_values(ascending=False)
industryVacancies = industryVacancies.head(5)
top5 = industryVacancies.sum();

industryVacancies.loc['Others']=tot-top5

colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen','lightpink']
explode = (0.1, 0.04, 0.04, 0.04, 0.04, 0.04) 
w , patches , text = plt.pie(industryVacancies,explode=explode,colors=colors,autopct='%1.1f%%', shadow=True,startangle=0)

plt.legend(patches,labels = industryVacancies.index,loc=6, bbox_to_anchor=(1, 0.5))
plt.axis('equal')
plt.title('Top 5 industries with maximum number of job vacancies')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:504: UserWarning: You have mixed positional and keyword arguments, some input will be discarded.
#   warnings.warn("You have mixed positional and keyword "

# %%
minMaxData=jobs.groupby(['job_category1'])['salary_minimum','salary_maximum'].mean()
minMaxData=minMaxData.reset_index()

length=len(minMaxData)
fig, ax=plt.subplots(figsize=(length,length/4))

xmarks=[i for i in range(1,length+1,1)]
plt.xticks(xmarks)
plt.plot(xmarks,minMaxData['salary_maximum'],c='black',label='Maximum Salary');
plt.plot(xmarks,minMaxData['salary_minimum'],c='blue',label='Minimum Salary');
ax.set_xticklabels(minMaxData.job_category1,rotation=90)
plt.legend(loc='upper right',fontsize=30,frameon=True)
plt.title("Max and  Min Salary of various job categories",fontsize=30)
ax.tick_params(labelsize=20)
plt.show()

# %%
#df=jobs.groupby(['job_industry1','experience_years'])['job_industry1','experience_years'].size()
df=jobs.groupby(['job_industry1','experience_years'])['num_vacancies'].sum()
df=df.reset_index()
df.columns=['job_industry1','exp','ct']
df=df.groupby('job_industry1')['exp','ct'].max()
df=df.reset_index()

#print(df)
length=len(df)
fig, ax=plt.subplots(figsize=(length/4,length))
pos=np.arange(length)

ymarks=[i for i in range(1,length+1,1)]
ax.set_yticks(ymarks)

colors=[]
half=df['ct'].mean()
for i in range(0,length,1):
    if (df['ct'].iloc[i]>half):
        df['ct'].iloc[i]%=half
        colors.append('orange')
        #ax.barh(pos[i],df['ct'].iloc[i],align='center',tick_label=df['job_industry1'].iloc[i],color='orange',label='Above Mean')
    else:
        colors.append('blue')
        #ax.barh(pos[i],df['ct'].iloc[i],align='center',tick_label=df['job_industry1'].iloc[i],color='blue',label='Below Mean')
ax.barh(pos,df['ct'],align='center',tick_label=df['job_industry1'],color=colors)
ax.set_yticklabels(df['job_industry1'],fontsize=25)
plt.xticks(fontsize=25)

ind=0

p1=mpatches.Patch(color='orange',label='Value = Value + mean')
p2=mpatches.Patch(color='blue',label='Value')

for i, v in enumerate(df['ct']):
        ax.text(v + 3, i -0.05 , str(df['exp'].iloc[ind]), color='black', fontsize=25)
        ind+=1
        
plt.title('Maximum number of vacancies with years of experience for every industry',fontsize=35,color='black')
plt.legend(handles=[p1,p2],loc=0,fontsize=35)
plt.show()
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\pandas\core\indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
